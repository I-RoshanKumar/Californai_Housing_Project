# %% [markdown]
# <a href="https://colab.research.google.com/github/I-RoshanKumar/Californai_Housing_Project/blob/main/California_Housing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
from sklearn.datasets import fetch_california_housing
california_housing=fetch_california_housing()

# %%
california_housing.data
# Out:
# array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#           39.37      , -121.24      ]])

# %%
X=california_housing.data

# %%
california_housing.target
# Out:
# array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894])

# %%
y=california_housing.target

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)
y_pred
# Out:
# array([2.01619341, 3.79163028, 1.17888515, ..., 0.5072016 , 1.96449578,
#        2.60749401])

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y_test,y_pred)
print(f'Mean Squared Error: {mse}')
accuracy=model.score(X_test,y_test)
print(f'Accuracy is {accuracy}')
# Out:
# Mean Squared Error: 0.5326362176872419
# Accuracy is 0.6036348004403642

# %%
plt.scatter(y_test, y_pred, color='red')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], '--k')
plt.xlabel('Actual Median House Value')
plt.ylabel('Predicted value')
plt.title('Linear Regression on California House DAtasets')
plt.show()
